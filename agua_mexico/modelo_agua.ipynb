# %%
import geopandas as gpd
import requests, zipfile
z = zipfile.ZipFile('C:/Users/Jorge/Documents/python_data/agua_mexico/Cuencas_hidrolOgicas_que_cuentan_con_reserva.zip')
z.extractall(os.path.join(os.getcwd(), 'data-agua'))
df = gpd.read_file('C:/Users/Jorge/Documents/python_data/agua_mexico/data-agua/Cuencas_hidrolOgicas_que_cuentan_con_reserva/Cuencas_hidrologicas_Reservas_Act757.shp')
df.plot()
# Out:
# <AxesSubplot: >

# %%
df_volume_water = df[['NO_CUENCA', 'NOMBRE_CUE', 'Vol_PU']]
df_volume_water.plot()
# Out:
# <AxesSubplot: >
